# %%
import requests
import json
import pandas as pd
from getpass import getpass
import folium
import os
from dotenv import load_dotenv
load_dotenv() # load_env
token = os.getenv("token")
from pymongo import MongoClient
import time
client = MongoClient("localhost:27017")
from folium import Choropleth, Circle, Marker, Icon, Map
from folium.plugins import HeatMap, MarkerCluster
client
# Out:
# MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True)

# %% [markdown]
# # Data Frames

# %%
# All the dataframes from the venues in Montreal

df_bars_mo = pd.read_csv("../DATA/bars_mo.csv")
df_schools_mo = pd.read_csv("../DATA/schools_mo.csv")
df_air_mo = pd.read_csv("../DATA/air_mo.csv")
df_starbucks_mo = pd.read_csv("../DATA/starbucks_mo.csv")
df_design_mo = pd.read_csv("../DATA/design_mo.csv")
df_vegan_mo = pd.read_csv("../DATA/vegan_mo.csv")

# %%
# All the dataframes from the venues in Toronto

df_bars_to = pd.read_csv("../DATA/bars_to.csv")
df_schools_to = pd.read_csv("../DATA/schools_to.csv")
df_air_to = pd.read_csv("../DATA/air_to.csv")
df_starbucks_to = pd.read_csv("../DATA/starbucks_to.csv")
df_design_to = pd.read_csv("../DATA/design_to.csv")
df_vegan_to = pd.read_csv("../DATA/vegan_to.csv")

# %%
# All the dataframes from the venues in Ottawa

df_bars_ot = pd.read_csv("../DATA/bars_ot.csv")
df_schools_ot = pd.read_csv("../DATA/schools_ot.csv")
df_air_ot = pd.read_csv("../DATA/air_ot.csv")
df_starbucks_ot = pd.read_csv("../DATA/starbucks_ot.csv")
df_design_ot = pd.read_csv("../DATA/design_ot.csv")
df_vegan_ot = pd.read_csv("../DATA/vegan_ot.csv")

# %%
# Function to map all the venues.

def build_map(df, type, map):
    for _, row in df.iterrows():
        if type == 'starbucks':
            icon = folium.Icon(
                color = "beige",
                icon_color = "white",
                icon = "fa-coffee",
                prefix = "fa",
            )
        if type == 'design':
            icon = folium.Icon(
                color = "darkblue",
                icon_color = "white",
                icon = "palette",
                prefix = "fa",
            )
        if type == 'bars':
            icon = folium.Icon(
                color = "black",
                icon_color = "white",
                icon = "beer-mug-empty",
                prefix = "fa",
            )
        if type == 'airport':
            icon = folium.Icon(
                color = "orange",
                icon_color = "white",
                icon = "fa-paper-plane",
                prefix = "fa",
            )
        if type == 'school':
            icon = folium.Icon(
                color = "lightred",
                icon_color = "white",
                icon = "fa-graduation-cap",
                prefix = "fa",
            )
        if type == 'vegan':
            icon = folium.Icon(
                color = "green",
                icon_color = "white",
                icon = "seedling",
                prefix = "fa",
            )
        
        new_marker = folium.Marker(location = [row["lat"], row["lon"]], icon=icon)
        new_marker.add_to(map)

# %% [markdown]
# # Coordinates

# %%
# montreal coordinates

lat_mo =  45.508210
lon_mo = -73.568340

#toronto coordinates

tor_lat = 43.654770 
tor_lon = -79.392346

#ottawa coordinates

ott_lat = 45.409977
ott_lon = -75.701231

# %% [markdown]
# # MONTREAL MAP

# %%
map_mo = Map(location = [lat_mo, lon_mo], zoom_start=12)

build_map(df_bars_mo, 'bars', map_mo)
build_map(df_schools_mo, 'school', map_mo)
build_map(df_air_mo, 'airport', map_mo)
build_map(df_starbucks_mo, 'starbucks', map_mo)
build_map(df_design_mo, 'design', map_mo)
build_map(df_vegan_mo, 'vegan', map_mo)


map_mo
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f92fd5a312a945d22119165baa972a83 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f92fd5a312a945d22119165baa972a83&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f92fd5a312a945d22119165baa972a83 = L.map(
#                 &quot;map_f92fd5a312a945d22119165baa972a83&quot;,
#                 {
#                     center: [45.50821, -73.56834],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4f91e6aeb7e697560dbf066f339dca70 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_f92fd5a312a945d22119165baa972a83);
#
#
#             var marker_d52db78b957717c34c0a974512bca6fa = L.marker(
#                 [45.509571, -73.571023],
#                 {}
#             ).addTo(map_f92fd5a312a945d22119165baa972a83);
#
#
#             var icon_d9bd7ffcd55ca3548a5d51c9455f6443 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;beer-mug-empty&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;black&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_d52db78b957717c34c0a974512bca6fa.setIcon(icon_d9bd7ffcd55ca3548a5d51c9455f6443);
#
#
#             var marker_5c081d9bc248cce73424bdc5c59c5580 = L.marker(
#                 [45.502195, -73.570593],
#                 {}
#             ).addTo(map_f92fd5a312a945d22119165baa972a83);
#
#
#             var icon_2a9103fdd0d358098ac94ff63fbb5773 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;beer-mug-empty&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;black&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_5c081d9bc248cce73424bdc5c59c5580.setIcon(icon_2a9103fdd0d358098ac94ff63fbb5773);
#
#
#             var marker_ba3231b52ee74edef0ffcf5fd09cf179 = L.marker(
#                 [45.515893, -73.564685],
#                 {}
#             ).addTo(map_f92fd5a312a945d22119165baa972a83);
#
#
#             var icon_c53f68f5eac7b88306cc2cd1e2baf0e0 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;beer-mug-empty&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;black&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_ba3231b52ee74edef0ffcf5fd09cf179.setIcon(icon_c53f68f5eac7b88306cc2cd1e2baf0e0);
#
#
#             var marker_7b7768dcb52d7138af6b905aa15378ae = L.marker(
#                 [45.507661, -73.564375],
#                 {}
#             ).addTo(map_f92fd5a312a945d22119165baa972a83);
#
#
#             var icon_66c0bf566f8edfe4c92a8c62e98ab1d5 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;beer-mug-empty&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;black&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_7b7768dcb52d7138af6b905aa15378ae.setIcon(icon_66c0bf566f8edfe4c92a8c62e98ab1d5);
#
#
#             var marker_bb81bd9b83215bfb81123b01477aea4d = L.marker(
#                 [45.510929, -73.565738],
#                 {}
#             ).addTo(map_f92fd5a312a945d22119165baa972a83);
#
#
#             var icon_7d76d4fe910d82d0610fd2664332c0bf = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;beer-mug-empty&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;black&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_bb81bd9b83215bfb81123b01477aea4d.setIcon(icon_7d76d4fe910d82d0610fd2664332c0bf);
#
#
#             var marker_111d043456889071ead7733dfe040fe9 = L.marker(
#                 [45.512194, -73.562146],
#                 {}
#             ).addTo(map_f92fd5a312a945d22119165baa972a83);
#
#
#             var icon_26b040001a55a640f938721af0b9b0a2 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;beer-mug-empty&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;black&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_111d043456889071ead7733dfe040fe9.setIcon(icon_26b040001a55a640f938721af0b9b0a2);
#
#
#             var marker_ba673fdf16a81bf0625edb32e60b605c = L.marker(
#                 [45.508519, -73.561303],
#                 {}
#             ).addTo(map_f92fd5a312a945d22119165baa972a83);
#
#
#             va

# %% [markdown]
# # TORONTO MAP

# %%
map_to = Map(location = [tor_lat, tor_lon], zoom_start=11)

build_map(df_bars_to, 'bars', map_to)
build_map(df_schools_to, 'school', map_to)
build_map(df_air_to, 'airport', map_to)
build_map(df_starbucks_to, 'starbucks', map_to)
build_map(df_design_to, 'design', map_to)
build_map(df_vegan_to, 'vegan', map_to)

map_to
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1a4f1035fa2bbc9a5373809e855de88d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1a4f1035fa2bbc9a5373809e855de88d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1a4f1035fa2bbc9a5373809e855de88d = L.map(
#                 &quot;map_1a4f1035fa2bbc9a5373809e855de88d&quot;,
#                 {
#                     center: [43.65477, -79.392346],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_99259487b861161ac2b9f4c6ca41360d = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_1a4f1035fa2bbc9a5373809e855de88d);
#
#
#             var marker_b50ebff38c910fb79ff31d83b383b359 = L.marker(
#                 [43.654588, -79.391728],
#                 {}
#             ).addTo(map_1a4f1035fa2bbc9a5373809e855de88d);
#
#
#             var icon_0a055ee1a6403559f4e1266713f81fc1 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;beer-mug-empty&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;black&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_b50ebff38c910fb79ff31d83b383b359.setIcon(icon_0a055ee1a6403559f4e1266713f81fc1);
#
#
#             var marker_fbcfbcacc39955c17e3beab5149516ba = L.marker(
#                 [43.648185, -79.39024],
#                 {}
#             ).addTo(map_1a4f1035fa2bbc9a5373809e855de88d);
#
#
#             var icon_25ad893e6fffb91cbb17cef831fbb0ee = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;beer-mug-empty&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;black&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_fbcfbcacc39955c17e3beab5149516ba.setIcon(icon_25ad893e6fffb91cbb17cef831fbb0ee);
#
#
#             var marker_78136445706d71bcba68c82fcbfdb09b = L.marker(
#                 [43.649093, -79.39319],
#                 {}
#             ).addTo(map_1a4f1035fa2bbc9a5373809e855de88d);
#
#
#             var icon_76ba2ba9548e5440a170507417568a62 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;beer-mug-empty&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;black&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_78136445706d71bcba68c82fcbfdb09b.setIcon(icon_76ba2ba9548e5440a170507417568a62);
#
#
#             var marker_601abc0dda203cd351719d1dbb4f6ac6 = L.marker(
#                 [43.65738, -79.38343],
#                 {}
#             ).addTo(map_1a4f1035fa2bbc9a5373809e855de88d);
#
#
#             var icon_3fed73e9a378540ae87cfd57dde4fb94 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;beer-mug-empty&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;black&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_601abc0dda203cd351719d1dbb4f6ac6.setIcon(icon_3fed73e9a378540ae87cfd57dde4fb94);
#
#
#             var marker_258f766cfe183388fe29d3c87681d573 = L.marker(
#                 [43.655472, -79.380321],
#                 {}
#             ).addTo(map_1a4f1035fa2bbc9a5373809e855de88d);
#
#
#             var icon_e6cf427b837d04eba3f400939666f33a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;beer-mug-empty&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;black&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_258f766cfe183388fe29d3c87681d573.setIcon(icon_e6cf427b837d04eba3f400939666f33a);
#
#
#             var marker_f6bce94fa2b93ea4db1eb707928b4b2a = L.marker(
#                 [43.658801, -79.394784],
#                 {}
#             ).addTo(map_1a4f1035fa2bbc9a5373809e855de88d);
#
#
#             var icon_196019195def6ab525b3ad02a0edaca9 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;beer-mug-empty&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;black&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_f6bce94fa2b93ea4db1eb707928b4b2a.setIcon(icon_196019195def6ab525b3ad02a0edaca9);
#
#
#             var marker_5f634a4b7579a96d09af303f84a26042 = L.marker(
#                 [43.654218, -79.400693],
#                 {}
#             ).addTo(map_1a4f1035fa2bbc9a5373809e855de88d);
#
#
#             var i

# %% [markdown]
# # OTTAWA MAP

# %%
map_ot = Map(location = [ott_lat, ott_lon], zoom_start=11)

build_map(df_bars_ot, 'bars', map_ot)
build_map(df_schools_ot, 'school', map_ot)
build_map(df_air_ot, 'airport', map_ot)
build_map(df_starbucks_ot, 'starbucks', map_ot)
build_map(df_design_ot, 'design', map_ot)
build_map(df_vegan_ot, 'vegan', map_ot)

map_ot
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_16915e422d6a9c48c4e3e566b5020b92 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_16915e422d6a9c48c4e3e566b5020b92&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_16915e422d6a9c48c4e3e566b5020b92 = L.map(
#                 &quot;map_16915e422d6a9c48c4e3e566b5020b92&quot;,
#                 {
#                     center: [45.409977, -75.701231],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_73923e14c106de723cd0e91fe98ecafe = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_16915e422d6a9c48c4e3e566b5020b92);
#
#
#             var marker_cbc1ec22536f7fb195826b41fbbbdab7 = L.marker(
#                 [45.410763, -75.693422],
#                 {}
#             ).addTo(map_16915e422d6a9c48c4e3e566b5020b92);
#
#
#             var icon_7abb48dab4d1223a94b810311e581c1a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;beer-mug-empty&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;black&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_cbc1ec22536f7fb195826b41fbbbdab7.setIcon(icon_7abb48dab4d1223a94b810311e581c1a);
#
#
#             var marker_82e7d9bfd4916844b3420a9ce89da859 = L.marker(
#                 [45.413846, -75.7004],
#                 {}
#             ).addTo(map_16915e422d6a9c48c4e3e566b5020b92);
#
#
#             var icon_c7adb74cb8fca558ba4b63519d1924af = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;beer-mug-empty&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;black&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_82e7d9bfd4916844b3420a9ce89da859.setIcon(icon_c7adb74cb8fca558ba4b63519d1924af);
#
#
#             var marker_fed63ca6e9a973238860ae932e5b6d3b = L.marker(
#                 [45.414938, -75.69574],
#                 {}
#             ).addTo(map_16915e422d6a9c48c4e3e566b5020b92);
#
#
#             var icon_edc8c2cfde9aaebdc111aee9544025ce = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;beer-mug-empty&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;black&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_fed63ca6e9a973238860ae932e5b6d3b.setIcon(icon_edc8c2cfde9aaebdc111aee9544025ce);
#
#
#             var marker_2c52e16177024b879464e37dd10f9077 = L.marker(
#                 [45.415919, -75.695382],
#                 {}
#             ).addTo(map_16915e422d6a9c48c4e3e566b5020b92);
#
#
#             var icon_8c71c7a6140e0704c6e27ef50d4746f6 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;beer-mug-empty&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;black&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_2c52e16177024b879464e37dd10f9077.setIcon(icon_8c71c7a6140e0704c6e27ef50d4746f6);
#
#
#             var marker_a98dd2e4a472e36ebee886429b8bdcba = L.marker(
#                 [45.413589, -75.701154],
#                 {}
#             ).addTo(map_16915e422d6a9c48c4e3e566b5020b92);
#
#
#             var icon_226f2dc5c793a221f703d107112aff16 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;beer-mug-empty&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;black&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_a98dd2e4a472e36ebee886429b8bdcba.setIcon(icon_226f2dc5c793a221f703d107112aff16);
#
#
#             var marker_3596a07f1a47e34a84f07ab03d0d7582 = L.marker(
#                 [45.416102, -75.695057],
#                 {}
#             ).addTo(map_16915e422d6a9c48c4e3e566b5020b92);
#
#
#             var icon_13763624bd06354dce343af5fe270964 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;beer-mug-empty&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;black&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_3596a07f1a47e34a84f07ab03d0d7582.setIcon(icon_13763624bd06354dce343af5fe270964);
#
#
#             var marker_2b01b0280a04f944909ba9dcdcecce0d = L.marker(
#                 [45.40846, -75.691204],
#                 {}
#             ).addTo(map_16915e422d6a9c48c4e3e566b5020b92);
#
#
#             var
